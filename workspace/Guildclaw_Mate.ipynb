# %% [markdown]
# # Guildclaw Mate (ноутбук)
#
# Проверки и подсказки **по ячейкам** — удобно, если не хочется ковырять терминал.
#
# То же из shell пода: `guildclaw-mate` или `guildclaw-mate info`.
#
# Эта папка — рабочая область агента OpenClaw (`/workspace/openclaw` в контейнере).

# %% [markdown]
# ## 1. Сводка: пути, ссылки RunPod, маскированные токены

# %%
import subprocess
subprocess.run(["guildclaw-mate", "info"], cwd="/workspace")

# %% [markdown]
# ## 2. Доктор: Hub, Pairing, LLM API и `openclaw.json`

# %%
import subprocess
subprocess.run(["guildclaw-mate", "doctor"], cwd="/workspace")

# %% [markdown]
# ## 3. Telegram: что в конфиге
#
# Токен из RunPod (`TELEGRAM_BOT_TOKEN`) при перезапуске пода дописывается в `openclaw.json` — см. **DEPLOY.md** в репозитории Guildclaw.

# %%
import subprocess
subprocess.run(["guildclaw-mate", "telegram"], cwd="/workspace")

# %% [markdown]
# ## 4. OpenClaw CLI (примеры)
#
# Раскомментируйте нужную строку и выполните ячейку.

# %%
import subprocess

# subprocess.run(["guildclaw-mate", "oc", "devices", "pending"], cwd="/workspace")
# subprocess.run(["guildclaw-mate", "oc", "nodes", "pending"], cwd="/workspace")
print("Раскомментируйте команду выше")
